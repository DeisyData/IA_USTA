# %%
from sklearn.datasets import make_regression
X, y = make_regression(n_samples=5, n_features=2, noise=1, random_state=42)

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
X, y = make_regression(n_samples=500, n_features=1, noise=30, random_state=42)
plt.scatter(X, y, c=y)

# %%
X.shape[0]
# Out:
# 500

# %%
X_b = np.c_[np.ones((X.shape[0], 1)), X]

# %%
X_b
# Out:
# array([[ 1.        , -0.80829829],
#        [ 1.        ,  0.09699596],
#        [ 1.        ,  0.47323762],
#        [ 1.        , -1.47852199],
#        [ 1.        , -0.3853136 ],
#        [ 1.        , -0.49300093],
#        [ 1.        ,  2.18980293],
#        [ 1.        ,  2.1221562 ],
#        [ 1.        ,  0.35778736],
#        [ 1.        ,  0.0976761 ],
#        [ 1.        , -0.79252074],
#        [ 1.        ,  0.09176078],
#        [ 1.        , -1.23086432],
#        [ 1.        , -0.34271452],
#        [ 1.        , -0.60021688],
#        [ 1.        ,  1.13556564],
#        [ 1.        , -0.60170661],
#        [ 1.        ,  0.06751848],
#        [ 1.        , -0.14237949],
#        [ 1.        , -0.60063869],
#        [ 1.        ,  1.76545424],
#        [ 1.        , -0.56228753],
#        [ 1.        ,  0.63391902],
#        [ 1.        ,  0.21397991],
#        [ 1.        ,  0.31125015],
#        [ 1.        ,  0.1990597 ],
#        [ 1.        , -0.01224677],
# ...

# %%
def predict(X, theta): # Hipotesis H(x)
    return np.dot(X, theta)

def compute_cost(X, y, theta):
    m = len(y)
    predictions = predict(X, theta)
    cost = (1/(2*m)) * np.sum(np.square(predictions - y))
    return cost

# %%
def gradient_descent(X, y, theta, alpha, iterations):
    m = len(y)
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        gradients = (1/(m)) * np.dot(X.T, (predict(X, theta) - y)) # m ecuación
        theta = theta - alpha * gradients
        cost_history[i] = compute_cost(X, y, theta)

    return theta, cost_history

# %%
theta = np.random.randn(2,1)
alpha = 0.01
iterations = 1000

# %%
theta, cost_history = gradient_descent(X_b, y.reshape(-1,1), theta, alpha, iterations)

# %%
print("Parámetros finales:", theta)
# Out:
# Parámetros finales: [[-1.17506472]
#  [62.90090662]]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, c=y)
plt.plot(X, X_b.dot(theta), color='red')
plt.title('Regresión lineal con Gradiente Descendente')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %%
plt.subplot(1, 2, 1)
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.xlabel('Iteraciones')
plt.ylabel('Costo')
plt.title('Progreso del entrenamiento')
# Out:
# Text(0.5, 1.0, 'Progreso del entrenamiento')

# %%
final_cost = compute_cost(X_b, y.reshape(-1,1), theta)
print("Error cuadrático medio después del entrenamiento:", final_cost)
# Out:
# Error cuadrático medio después del entrenamiento: 2195.212341257616
